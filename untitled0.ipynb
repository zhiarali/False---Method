# %% [markdown]
# <a href="https://colab.research.google.com/github/zhiarali/False---Method/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/Demo-Behavioral-Factors-in-Alcohol/-Demographic-and-Behavioral-Factors-in-Alcohol-Related-Incidents/main/alcoholic_people.CSV'
mydata = pd.read_csv(url , encoding = 'ISO-8859-1' , delimiter= ',')

# %%
# seed to generate same random forall students
np.random.seed(42)

# %%
mydata.head(5)
# Out:
#    Age  Gender Education_Level Car_Accidents Deaths_by_Alcohol    Country
# 0   25    Male     High School           Yes                No       Iraq
# 1   42  Female      Bachelor's            No               Yes     Turkey
# 2   35  Female        Master's           Yes               Yes  Australia
# 3   50    Male       Doctorate            No                No      Egypt
# 4   28  Female     High School           Yes                No    England

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                507 non-null    int64
#  1   Gender             507 non-null    object
#  2   Education_Level    507 non-null    object
#  3   Car_Accidents      507 non-null    object
#  4   Deaths_by_Alcohol  507 non-null    object
#  5   Country            507 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 23.9+ KB

# %%
mydata.describe()
# Out:
#               Age
# count  507.000000
# mean    35.889546
# std      8.305412
# min     22.000000
# 25%     28.000000
# 50%     36.000000
# 75%     43.000000
# max     50.000000

# %%
mydata.hist(['Age'], figsize=(7,5))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=mydata)
# sns.boxplot(x="Gender", orient= "h", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['Education_Level'],mydata['Country'] )
# Out:
# Country          Australia  Egypt  England  Germany  Iraq  Turkey  USA
# Education_Level
# Bachelor's              23     25       20       23    16      26   24
# Doctorate               15     13       11       12    17      12   12
# High School             22     21       26       21    24      22   21
# Master's                13     13       15       16    16      13   15

# %%
pd.crosstab(mydata['Country'],mydata['Gender'] )
# Out:
# Gender     Female  Male
# Country
# Australia      31    42
# Egypt          34    38
# England        34    38
# Germany        32    40
# Iraq           33    40
# Turkey         36    37
# USA            33    39

# %%
sns.countplot(x="Education_Level", hue="Gender", data=mydata)
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Education_Level', 'Gender'],
                     columns=[ 'Deaths_by_Alcohol'], aggfunc=len)
# Out:
#                        Age     Car_Accidents     Country
# Deaths_by_Alcohol       No Yes            No Yes      No Yes
# Education_Level Gender
# Bachelor's      Female  42  30            42  30      42  30
#                 Male    14  71            14  71      14  71
# Doctorate       Female   1  29             1  29       1  29
#                 Male    27  35            27  35      27  35
# High School     Female  49  21            49  21      49  21
#                 Male    47  40            47  40      47  40
# Master's        Female  25  36            25  36      25  36
#                 Male    22  18            22  18      22  18

# %%
mydata['Age'].std()
# Out:
# 8.305412135614496

# %%
mydata['Age'].mean()
# Out:
# 35.88954635108481

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Education_Level')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Country')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
alcoholic = pd.read_csv(url).dropna() # some rows are missing data

# %%
alcoholic
# Out:
#      Age  Gender Education_Level Car_Accidents Deaths_by_Alcohol    Country
# 0     25    Male     High School           Yes                No       Iraq
# 1     42  Female      Bachelor's            No               Yes     Turkey
# 2     35  Female        Master's           Yes               Yes  Australia
# 3     50    Male       Doctorate            No                No      Egypt
# 4     28  Female     High School           Yes                No    England
# ..   ...     ...             ...           ...               ...        ...
# 502   48  Female     High School           Yes                No        USA
# 503   33    Male     High School           Yes                No     Turkey
# 504   45    Male     High School            No                No    Germany
# 505   26  Female        Master's           Yes                No       Iraq
# 506   41    Male     High School            No                No  Australia
#
# [507 rows x 6 columns]

# %%
np.unique(alcoholic.Deaths_by_Alcohol, return_counts=True)
# Out:
# (array(['No', 'Yes'], dtype=object), array([227, 280]))

# %%
died_because_of_alcohol = alcoholic[alcoholic.Deaths_by_Alcohol == 'Yes']

# %%
died_because_of_alcohol
# Out:
#      Age  Gender Education_Level Car_Accidents Deaths_by_Alcohol    Country
# 1     42  Female      Bachelor's            No               Yes     Turkey
# 2     35  Female        Master's           Yes               Yes  Australia
# 5     37    Male     High School           Yes               Yes        USA
# 7     48  Female        Master's           Yes               Yes    Germany
# 8     33    Male       Doctorate           Yes               Yes       Iraq
# ..   ...     ...             ...           ...               ...        ...
# 491   39  Female       Doctorate           Yes               Yes       Iraq
# 492   26    Male      Bachelor's           Yes               Yes  Australia
# 494   50    Male        Master's           Yes               Yes    England
# 496   42    Male      Bachelor's            No               Yes     Turkey
# 497   35    Male        Master's           Yes               Yes    Germany
#
# [280 rows x 6 columns]

# %%
np.unique(died_because_of_alcohol.Country, return_counts=True)
# Out:
# (array(['Australia', 'Egypt', 'England', 'Germany', 'Iraq', 'Turkey',
#         'USA'], dtype=object),
#  array([44, 39, 39, 40, 41, 40, 37]))

# %%
_ = sns.boxplot(x='Country', y='Age', hue='Gender', data=died_because_of_alcohol)

# %%
f = died_because_of_alcohol[died_because_of_alcohol.Gender == 'Female']['Age'].to_numpy()
f
# Out:
# array([42, 35, 48, 26, 31, 39, 34, 36, 22, 46, 47, 36, 39, 48, 39, 34, 32,
#        36, 22, 46, 47, 36, 39, 25, 42, 28, 29, 48, 26, 31, 39, 34, 36, 22,
#        46, 47, 36, 39, 42, 48, 26, 31, 39, 34, 32, 36, 35, 46, 47, 36, 39,
#        42, 48, 26, 31, 39, 34, 32, 36, 22, 46, 47, 36, 39, 42, 48, 26, 31,
#        39, 34, 32, 36, 22, 46, 47, 36, 39, 42, 48, 26, 31, 39, 34, 32, 36,
#        22, 31, 27, 46, 47, 32, 36, 41, 45, 39, 42, 26, 31, 32, 36, 46, 38,
#        39, 42, 48, 39, 34, 32, 36, 22, 27, 33, 46, 47, 36, 39])

# %%
m = died_because_of_alcohol[died_because_of_alcohol.Gender == 'Male']['Age'].to_numpy()
m
# Out:
# array([37, 33, 47, 46, 44, 38, 31, 27, 33, 29, 38, 32, 41, 45, 26, 37, 33,
#        26, 31, 47, 46, 44, 49, 43, 38, 31, 27, 33, 29, 38, 32, 41, 45, 26,
#        50, 35, 50, 37, 33, 47, 46, 44, 43, 38, 31, 27, 33, 29, 38, 32, 41,
#        45, 26, 50, 35, 37, 33, 47, 46, 44, 49, 43, 38, 22, 31, 27, 33, 29,
#        38, 32, 41, 45, 26, 50, 35, 37, 33, 47, 46, 44, 49, 43, 38, 31, 27,
#        33, 29, 38, 32, 41, 45, 26, 50, 35, 37, 33, 47, 46, 44, 49, 43, 38,
#        31, 27, 33, 29, 38, 32, 41, 45, 26, 50, 35, 37, 33, 47, 46, 44, 49,
#        43, 38, 33, 29, 38, 26, 50, 35, 47, 39, 34, 46, 44, 49, 43, 38, 22,
#        31, 27, 33, 29, 45, 26, 50, 35, 37, 33, 26, 31, 47, 46, 44, 49, 43,
#        38, 31, 29, 38, 32, 41, 45, 26, 50, 42, 35])

# %%
fbar = f.mean()
fbar
# Out:
# 36.724137931034484

# %%
mbar = m.mean()
mbar
# Out:
# 37.78048780487805
